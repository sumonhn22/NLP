# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# %%
imdb, info = tfds.load("imdb_reviews", with_info=True, as_supervised=True)

# %%
train_data, test_data = imdb['train'], imdb['test']

# %%
training_sentences = []
training_labels = []
testing_sentences = []
testing_labels = []

for s, l in train_data:
    training_sentences.append(str(s.numpy()))
    training_labels.append(l.numpy())

for s, l in test_data:
    testing_sentences.append(str(s.numpy()))
    testing_labels.append(l.numpy())

training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)

# %%
vocab_size = 1000
embedding_dim = 16
max_length = 120
trunc_type='post'
oov_tok = "<OOV>"

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences,maxlen=max_length, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length)
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

print(decode_review(padded[1]))
print(training_sentences[1])
# Out:
# ? ? ? ? ? ? ? b'i have been known to fall <OOV> during films but this is usually due to a <OOV> of things including really <OOV> being <OOV> and <OOV> on the <OOV> and having just <OOV> a lot however on this <OOV> i <OOV> <OOV> because the film was <OOV> the plot development was <OOV> <OOV> slow and boring things seemed to happen but with no <OOV> of what was <OOV> them or why i admit i may have <OOV> part of the film but i watched the <OOV> of it and everything just seemed to happen of its own <OOV> without any real <OOV> for anything else i <OOV> recommend this film at all '
# b'I have been known to fall asleep during films, but this is usually due to a combination of things including, really tired, being warm and comfortable on the sette and having just eaten a lot. However on this occasion I fell asleep because the film was rubbish. The plot development was constant. Constantly slow and boring. Things seemed to happen, but with no explanation of what was causing them or why. I admit, I may have missed part of the film, but i watched the majority of it and everything just seemed to happen of its own accord without any real concern for anything else. I cant recommend this film at all.'

# %%
#################          Model Definition  :  best    ####################
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
#################          Model Definition with Conv1D  :  overfitting       ####################
# model = tf.keras.Sequential([
#     tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
#     tf.keras.layers.Conv1D(128, 5, activation='relu'),
#     tf.keras.layers.GlobalAveragePooling1D(),
#     ###  tf.keras.layers.Dense(8, activation='relu', kernel_regularizer = tf.keras.regularizers.l2(0.01)),
#     tf.keras.layers.Dense(6, activation='relu'),
#     ##  tf.keras.layers.Dropout(.25),
#     tf.keras.layers.Dense(1, activation='sigmoid')
# ])

# %%
#######################        MBidirectional with LSTM, overfitting            #######################
# model = tf.keras.Sequential([
#     tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
#     tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
#     tf.keras.layers.Dense(6, activation='relu'),
#     tf.keras.layers.Dense(1, activation='sigmoid')
# ])

# %%
###################             Bidirectional with GRU,  overfitting         ##############################
# model = tf.keras.Sequential([
#     tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
#     tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
#     tf.keras.layers.Dense(6, activation='relu'),
#     tf.keras.layers.Dense(1, activation='sigmoid')
# ])

# %%
model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])
model.summary()

history = model.fit(padded, training_labels_final, epochs= 25, validation_data=(testing_padded, testing_labels_final))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 120, 16)           16000
#
#  global_average_pooling1d_2   (None, 16)               0
#  (GlobalAveragePooling1D)
#
#  dense_4 (Dense)             (None, 6)                 102
#
#  dense_5 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 16,109
# Trainable params: 16,109
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 782/782 [==============================] - 4s 4ms/step - loss: 0.6041 - accuracy: 0.6884 - val_loss: 0.4537 - val_accuracy: 0.8070
# Epoch 2/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.4340 - accuracy: 0.8040 - val_loss: 0.3928 - val_accuracy: 0.8222
# Epoch 3/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.4038 - accuracy: 0.8161 - val_loss: 0.3760 - val_accuracy: 0.8295
# Epoch 4/25
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3949 - accuracy: 0.8224 - val_loss: 0.3739 - val_accuracy: 0.8300
# Epoch 5/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3905 - accuracy: 0.8255 - val_loss: 0.3743 - val_accuracy: 0.8298
# Epoch 6/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3890 - accuracy: 0.8249 - val_loss: 0.3751 - val_accuracy: 0.8301
# Epoch 7/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3880 - accuracy: 0.8252 - val_loss: 0.3752 - val_accuracy: 0.8286
# Epoch 8/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3872 - accuracy: 0.8270 - val_loss: 0.3824 - val_accuracy: 0.8240
# Epoch 9/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3864 - accuracy: 0.8275 - val_loss: 0.3764 - val_accuracy: 0.8278
# Epoch 10/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3865 - accuracy: 0.8264 - val_loss: 0.3761 - val_accuracy: 0.8268
# Epoch 11/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3867 - accuracy: 0.8274 - val_loss: 0.3794 - val_accuracy: 0.8277
# Epoch 12/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3861 - accuracy: 0.8271 - val_loss: 0.3791 - val_accuracy: 0.8264
# Epoch 13/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3855 - accuracy: 0.8270 - val_loss: 0.3783 - val_accuracy: 0.8276
# Epoch 14/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3853 - accuracy: 0.8276 - val_loss: 0.3796 - val_accuracy: 0.8275
# Epoch 15/25
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3857 - accuracy: 0.8257 - val_loss: 0.3777 - val_accuracy: 0.8264
# Epoch 16/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3851 - accuracy: 0.8274 - val_loss: 0.3781 - val_accuracy: 0.8264
# Epoch 17/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3850 - accuracy: 0.8268 - val_loss: 0.3785 - val_accuracy: 0.8269
# Epoch 18/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3841 - accuracy: 0.8281 - val_loss: 0.3791 - val_accuracy: 0.8274
# Epoch 19/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3855 - accuracy: 0.8268 - val_loss: 0.3811 - val_accuracy: 0.8253
# Epoch 20/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3849 - accuracy: 0.8282 - val_loss: 0.3782 - val_accuracy: 0.8271
# Epoch 21/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3843 - accuracy: 0.8276 - val_loss: 0.3814 - val_accuracy: 0.8260
# Epoch 22/25
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3845 - accuracy: 0.8286 - val_loss: 0.3791 - val_accuracy: 0.8269
# Epoch 23/25
# 782/782 [==============================] - 3s 3ms/step - loss: 0.3840 - accuracy: 0.8274 - val_loss: 0.3784 - val_accuracy: 0.8266
# Epoch 24/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3843 - accuracy: 0.8283 - val_loss: 0.3800 - val_accuracy: 0.8246
# Epoch 25/25
# 782/782 [==============================] - 3s 4ms/step - loss: 0.3843 - accuracy: 0.8261 - val_loss: 0.3785 - val_accuracy: 0.8261

# %%
#################          plotting results     ###########################
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation (accuracy)')
plt.legend()
plt.show()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation (loss) ')
plt.legend()
plt.show()
