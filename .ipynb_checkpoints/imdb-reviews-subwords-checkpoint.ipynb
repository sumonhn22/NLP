# %% [markdown]
# # IMDB data sets with subwords (multiple Layer GRU)

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow_datasets as tfds
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.7.0

# %%
# Getting the data
dataset, info = tfds.load('imdb_reviews/subwords8k', with_info=True, as_supervised=True)
train_dataset, test_dataset = dataset['train'], dataset['test']
# Out:
# WARNING:absl:TFDS datasets with text encoding are deprecated and will be removed in a future version. Instead, you should use the plain text version and tokenize the text using `tensorflow_text` (See: https://www.tensorflow.org/tutorials/tensorflow_text/intro#tfdata_example)
# Downloading and preparing dataset imdb_reviews/subwords8k/1.0.0 (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/subwords8k/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/subwords8k/1.0.0.incomplete1VBV2E/imdb_reviews-train.tfrecord
#   0%|          | 0/25000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/subwords8k/1.0.0.incomplete1VBV2E/imdb_reviews-test.tfrecord
#   0%|          | 0/25000 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/subwords8k/1.0.0.incomplete1VBV2E/imdb_reviews-unsupervised.tfrecord
#   0%|          | 0/50000 [00:00<?, ? examples/s]
# WARNING:absl:Dataset is using deprecated text encoder API which will be removed soon. Please use the plain_text version of the dataset and migrate to `tensorflow_text`.
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/subwords8k/1.0.0. Subsequent calls will reuse this data.

# %%
tokenizer = info.features['text'].encoder

# %%
BUFFER_SIZE = 10000
BATCH_SIZE = 64

train_dataset = train_dataset.shuffle(BUFFER_SIZE)
train_dataset = train_dataset.padded_batch(BATCH_SIZE, tf.compat.v1.data.get_output_shapes(train_dataset))
test_dataset = test_dataset.padded_batch(BATCH_SIZE, tf.compat.v1.data.get_output_shapes(test_dataset))

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(tokenizer.vocab_size, 16),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
NUM_EPOCHS = 10
history = model.fit(train_dataset, epochs=NUM_EPOCHS, validation_data=test_dataset)
# Out:
# Epoch 1/10
# 391/391 [==============================] - 10s 17ms/step - loss: 0.6867 - accuracy: 0.5778 - val_loss: 0.6633 - val_accuracy: 0.7534
# Epoch 2/10
# 391/391 [==============================] - 7s 17ms/step - loss: 0.5790 - accuracy: 0.7573 - val_loss: 0.4983 - val_accuracy: 0.8184
# Epoch 3/10
# 391/391 [==============================] - 7s 17ms/step - loss: 0.4305 - accuracy: 0.8361 - val_loss: 0.3913 - val_accuracy: 0.8571
# Epoch 4/10
# 391/391 [==============================] - 7s 17ms/step - loss: 0.3424 - accuracy: 0.8750 - val_loss: 0.3494 - val_accuracy: 0.8629
# Epoch 5/10
# 391/391 [==============================] - 7s 17ms/step - loss: 0.2992 - accuracy: 0.8900 - val_loss: 0.3256 - val_accuracy: 0.8734
# Epoch 6/10
# 391/391 [==============================] - 7s 17ms/step - loss: 0.2709 - accuracy: 0.9008 - val_loss: 0.3151 - val_accuracy: 0.8782
# Epoch 7/10
# 391/391 [==============================] - 7s 17ms/step - loss: 0.2468 - accuracy: 0.9102 - val_loss: 0.3101 - val_accuracy: 0.8790
# Epoch 8/10
# 391/391 [==============================] - 7s 17ms/step - loss: 0.2297 - accuracy: 0.9184 - val_loss: 0.3066 - val_accuracy: 0.8813
# Epoch 9/10
# 391/391 [==============================] - 7s 17ms/step - loss: 0.2148 - accuracy: 0.9227 - val_loss: 0.3285 - val_accuracy: 0.8695
# Epoch 10/10
# 391/391 [==============================] - 7s 17ms/step - loss: 0.2013 - accuracy: 0.9283 - val_loss: 0.3203 - val_accuracy: 0.8772

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# %%
plot_graphs(history, 'accuracy')

# %%
plot_graphs(history, 'loss')
